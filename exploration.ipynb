# %% [markdown]
# # Project

# %% [markdown]
# ## Imports

# %%
# Numerical computing
import numpy as np

# Data manipulation
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning (scikit-learn)
import sklearn

# %%
df_emails = pd.read_csv("data/epstein-emails-2026-02-18.csv")
df_flights = pd.read_csv("data/epstein-flights-2026-03-16.csv")
df_persons = pd.read_csv("data/epstein-persons-2026-03-16.csv")

# %% [markdown]
# ## Data Cleaning and Preparation

# %% [markdown]
# ### Epstein Emails

# %%
df_emails.head()
# Out:
#          Date                                               From  \
# 0  2019-07-14            Quora Digest [digest-noreply@quora.com]
# 1  2019-07-09  Intelligence Squared [info@intelligencesquared...
# 2  2019-07-07            Quora Digest [digest-noreply@quora.com]
# 3  2019-07-06                                    Reid Weingarten
# 4  2019-07-06                                    Jeffrey Epstein
#
#                 From Email                     To  \
# 0                      NaN  jeevacation@gmail.com
# 1                      NaN  jeevacation@gmail.com
# 2                      NaN  jeevacation@gmail.com
# 3  rweingarten@steptoe.com        Jeffrey Epstein
# 4    je@jeffreyepstein.com        Reid Weingarten
#
#                                              Subject  \
# 0                         Is Denmark going bankrupt?
# 1  John Humphrys: The Terrier of Today, in conver...
# 2                        What is the French paradox?
# ...

# %%
print("Number of rows :", df_emails.shape[0])
print("Number of cols :", df_emails.shape[1])
# Out:
# Number of rows : 9493
# Number of cols : 7

# %%
df_emails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9493 entries, 0 to 9492
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            9493 non-null   object
#  1   From            9180 non-null   object
#  2   From Email      3893 non-null   object
#  3   To              8616 non-null   object
#  4   Subject         9229 non-null   object
#  5   Body (excerpt)  9493 non-null   object
#  6   Tags            5293 non-null   object
# dtypes: object(7)
# memory usage: 519.3+ KB

# %%
# find mising values
df_emails.isnull().sum()
# Out:
# Date                 0
# From               313
# From Email        5600
# To                 877
# Subject            264
# Body (excerpt)       0
# Tags              4200
# dtype: int64

# %%
str_cols = ["From",	"From Email",	"To",	"Subject",	"Body (excerpt)",	"Tags"]
df_emails_string = pd.DataFrame()
for c in str_cols:
    if c in df_emails.columns:
        df_emails[c] = df_emails[c].astype("string")
        df_emails_string[c] = df_emails[c]

# date column
if "Date" in df_emails.columns:
    df_emails["Date"] = pd.to_datetime(df_emails["Date"],errors ="coerce")
    df_emails_datetime = df_emails["Date"]

df_emails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9493 entries, 0 to 9492
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            9493 non-null   datetime64[ns]
#  1   From            9180 non-null   string
#  2   From Email      3893 non-null   string
#  3   To              8616 non-null   string
#  4   Subject         9229 non-null   string
#  5   Body (excerpt)  9493 non-null   string
#  6   Tags            5293 non-null   string
# dtypes: datetime64[ns](1), string(6)
# memory usage: 519.3 KB

# %% [markdown]
# ### Epstein Flights

# %%
df_flights.head()
# Out:
#          Date                 Origin              Destination  \
# 0  2002-09-28         Kigali, Rwanda       Maputo, Mozambique
# 1  2002-09-25           Accra, Ghana           Abuja, Nigeria
# 2  2002-09-22       Azores, Portugal             Accra, Ghana
# 3  2002-09-21  JFK International, NY         Azores, Portugal
# 4  2002-09-29     Maputo, Mozambique  Cape Town, South Africa
#
#               Aircraft                                         Passengers  \
# 0  N908JE (Boeing 727)  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 1  N908JE (Boeing 727)  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 2  N908JE (Boeing 727)  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 3  N908JE (Boeing 727)  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 4  N908JE (Boeing 727)  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
#
#            Pilot                                              Notes
# 0  David Rodgers  Africa trip - Rwanda to Mozambique. Ira Magazi...
# ...

# %%
print("Number of rows :", df_flights.shape[0])
print("Number of cols :", df_flights.shape[1])
# Out:
# Number of rows : 3615
# Number of cols : 7

# %%
df_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3615 entries, 0 to 3614
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         3615 non-null   object
#  1   Origin       3615 non-null   object
#  2   Destination  3615 non-null   object
#  3   Aircraft     3615 non-null   object
#  4   Passengers   2526 non-null   object
#  5   Pilot        875 non-null    object
#  6   Notes        3597 non-null   object
# dtypes: object(7)
# memory usage: 197.8+ KB

# %%
# find mising values
df_flights.isnull().sum()
# Out:
# Date              0
# Origin            0
# Destination       0
# Aircraft          0
# Passengers     1089
# Pilot          2740
# Notes            18
# dtype: int64

# %%
str_cols = ["Origin","Destination","Aircraft","Passengers","Pilot","Notes" ]
df_flights_string = pd.DataFrame()
for c in str_cols:
    if c in df_flights.columns:
        df_flights[c] = df_flights[c].astype("string")
        df_flights_string[c] = df_flights[c]

# date column
if "Date" in df_flights.columns:
    df_flights["Date"] = pd.to_datetime(df_flights["Date"],errors ="coerce")
    df_flights_datetime = df_flights["Date"]

df_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3615 entries, 0 to 3614
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         3615 non-null   datetime64[ns]
#  1   Origin       3615 non-null   string
#  2   Destination  3615 non-null   string
#  3   Aircraft     3615 non-null   string
#  4   Passengers   2526 non-null   string
#  5   Pilot        875 non-null    string
#  6   Notes        3597 non-null   string
# dtypes: datetime64[ns](1), string(6)
# memory usage: 197.8 KB

# %% [markdown]
# ### Epstein Persons

# %%
df_persons.head()
# Out:
#                 Name   Category  \
# 0    Jeffrey Epstein      other
# 1  Ghislaine Maxwell  associate
# 2       Sarah Kellen  associate
# 3       Adriana Ross  associate
# 4      Larry Visoski  associate
#
#                                                  Bio  \
# 0  Convicted sex offender; financier; died in cus...
# 1  Convicted sex trafficker serving 20 years; Eps...
# 2  Epstein's primary scheduler; named co-conspira...
# 3  Polish former model; Epstein assistant; named ...
# 4  Epstein's chief pilot for 28 years; key Maxwel...
#
#                                          Aliases  Flights  Documents  \
# 0           Jeffrey Edward Epstein; Jeff Epstein     2027     736258
# 1                                          G-Max     1139      20390
# 2     Sarah Kellen Vickers; Sarah Lyn Kensington      672        636
# 3                               Adriana Mucinska      145        138
# 4  Lawrence Visoski; Lvjet; LVJET; lvjet@aol.com      439      27453
#
# ...

# %%
print("Number of rows :", df_persons.shape[0])
print("Number of cols :", df_persons.shape[1])
# Out:
# Number of rows : 1498
# Number of cols : 9

# %%
df_persons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           1498 non-null   object
#  1   Category       1498 non-null   object
#  2   Bio            1496 non-null   object
#  3   Aliases        858 non-null    object
#  4   Flights        1498 non-null   int64
#  5   Documents      1498 non-null   int64
#  6   Connections    1498 non-null   int64
#  7   In Black Book  1498 non-null   object
#  8   Nationality    857 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 105.5+ KB

# %%
# find mising values
df_persons.isnull().sum()
# Out:
# Name               0
# Category           0
# Bio                2
# Aliases          640
# Flights            0
# Documents          0
# Connections        0
# In Black Book      0
# Nationality      641
# dtype: int64

# %%
string_cols = [
    "Name",
    "Bio",
    "Aliases",
    "Flights",
    "Documents",
    "Connections"
]

# Convert string columns
for col in string_cols:
    if col in df_persons.columns:
        df_persons[col] = df_persons[col].astype("string")

category_cols = [
    "Category",
    "Nationality",
    "In Black Book"
]

df_persons_cat = pd.DataFrame()   # ← FIXED

for col in category_cols:
    if col in df_persons.columns:
        df_persons[col] = (
            df_persons[col]
            .astype("string")
            .str.strip()
            .str.lower()
            .astype("category")
        )
        df_persons_cat[col] = df_persons[col]

df_persons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           1498 non-null   string
#  1   Category       1498 non-null   category
#  2   Bio            1496 non-null   string
#  3   Aliases        858 non-null    string
#  4   Flights        1498 non-null   string
#  5   Documents      1498 non-null   string
#  6   Connections    1498 non-null   string
#  7   In Black Book  1498 non-null   category
#  8   Nationality    857 non-null    category
# dtypes: category(3), string(6)
# memory usage: 78.3 KB

# %%
# Categorical Features

for c in df_persons_cat:
    print(f"\n{c}")
    print(df_persons_cat[c].value_counts(normalize=True))
# Out:
# Category
# Category
# associate                0.425901
# business                 0.180240
# other                    0.081442
# politician               0.074099
# celebrity                0.071429
# academic                 0.068091
# legal                    0.046729
# socialite                0.029372
# military-intelligence    0.009346
# royalty                  0.006676
# staff                    0.004673
# social                   0.001335
# person-of-interest       0.000668
# Name: proportion, dtype: float64
#
# Nationality
# Nationality
# american            0.640607
# british             0.089848
# french              0.031505
# russian             0.023337
# norwegian           0.015169
#                       ...
# kazakhstani         0.001167
# canadian-british    0.001167
# lebanese            0.001167
# lebanese-french     0.001167
# yemeni              0.001167
# Name: proportion, Length: 93, dtype: float64
#
# In Black Book
# In Black Book
# no     0.776368
# ...

# %% [markdown]
# ## Network Analisis
#
# "Who talked to him and flew with him the most?"
# * (Uses: Emails & Flights data)

# %% [markdown]
# ### Who flew with JE the most

# %%
df_passangers = df_flights[["Passengers"]].copy()
df_passangers.head()
# Out:
#                                           Passengers
# 0  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 1  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 2  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 3  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 4  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...

# %%
print("Shape : ", df_passangers.shape)
print("Number of Nan : ",df_passangers.isna().sum())

df_passangers = df_passangers.dropna()

print("Shape : ", df_passangers.shape)
print("Number of Nan : ",df_passangers.isna().sum())

df_passangers.head()
# Out:
# Shape :  (3615, 1)
# Number of Nan :  Passengers    1089
# dtype: int64
# Shape :  (2526, 1)
# Number of Nan :  Passengers    0
# dtype: int64
#                                           Passengers
# 0  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 1  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 2  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 3  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...
# 4  Jeffrey Epstein; Ghislaine Maxwell; Bill Clint...

# %%
df_passangers = df_passangers["Passengers"].str.split(";", expand=True)
df_passangers = df_passangers.fillna("")
df_passangers.head()
# Out:
#                 0                   1              2           3   \
# 0  Jeffrey Epstein   Ghislaine Maxwell   Bill Clinton   Doug Band
# 1  Jeffrey Epstein   Ghislaine Maxwell   Bill Clinton   Doug Band
# 2  Jeffrey Epstein   Ghislaine Maxwell   Bill Clinton   Doug Band
# 3  Jeffrey Epstein   Ghislaine Maxwell   Bill Clinton   Doug Band
# 4  Jeffrey Epstein   Ghislaine Maxwell   Bill Clinton   Doug Band
#
#               4              5                 6                 7   \
# 0   Kevin Spacey   Chris Tucker   Chauntae Davies   Casey Wasserman
# 1   Kevin Spacey   Chris Tucker   Chauntae Davies   Casey Wasserman
# 2   Kevin Spacey   Chris Tucker   Chauntae Davies   Casey Wasserman
# 3   Kevin Spacey   Chris Tucker   Chauntae Davies   Casey Wasserman
# 4   Kevin Spacey   Chris Tucker   Chauntae Davies   Casey Wasserman
#
#                  8                  9   ...              12            13  \
# 0   Laura Wasserman   Andrea Mitrovich  ...   Rodney Slater   Gayle Smith
# ...

# %%
df_passangers = (
    df_flights["Passengers"]
    .dropna()
    .apply(lambda x: list(dict.fromkeys([p.strip() for p in x.split(";")])))
)
df_passangers = pd.DataFrame(df_passangers.tolist())

# %%
df_passangers.head(30)
# Out:
#                  0                  1                  2                  3   \
# 0   Jeffrey Epstein  Ghislaine Maxwell       Bill Clinton          Doug Band
# 1   Jeffrey Epstein  Ghislaine Maxwell       Bill Clinton          Doug Band
# 2   Jeffrey Epstein  Ghislaine Maxwell       Bill Clinton          Doug Band
# 3   Jeffrey Epstein  Ghislaine Maxwell       Bill Clinton          Doug Band
# 4   Jeffrey Epstein  Ghislaine Maxwell       Bill Clinton          Doug Band
# 5   Jeffrey Epstein  Ghislaine Maxwell       Bill Clinton          Doug Band
# 6      Bill Clinton       Kevin Spacey       Chris Tucker    Jeffrey Epstein
# 7      Bill Clinton       Kevin Spacey       Chris Tucker    Jeffrey Epstein
# 8      Bill Clinton       Kevin Spacey       Chris Tucker    Jeffrey Epstein
# 9      Bill Clinton       Kevin Spacey       Chris Tucker    Jeffrey Epstein
# 10     Bill Clinton       Kevin Spacey       Chris Tucker    Jeffrey Epstein
# ...

# %%
df_passangers = df_passangers.stack()
df_passangers = df_passangers[df_passangers != ""]

df_passangers_total = df_passangers.value_counts().to_frame(name="Count")
df_passangers_total = df_passangers_total.reset_index()
df_passangers_total.columns = ["Passenger", "Count"]

# %%
df_passangers_total.head(30)
# Out:
#               Passenger  Count
# 0       Jeffrey Epstein   2013
# 1     Ghislaine Maxwell   1134
# 2          Sarah Kellen    672
# 3         Larry Visoski    438
# 4      Nadia Marcinkova    264
# 5           Emmy Tayler    200
# 6        Larry Morrison     98
# 7          Lesley Groff     92
# 8                   A P     90
# 9      Virginia Roberts     76
# 10     Andrea Mitrovich     73
# 11         Bill Hammond     66
# 12         Bill Clinton     63
# 13        Sophie Biddle     61
# 14        Brent Tindall     60
# 15            Doug Band     59
# 16      Jean-Luc Brunel     51
# 17         Teala Davies     50
# 18      Alan Dershowitz     45
# 19  Clare Hazell-Iveagh     40
# 20        Shelley Lewis     39
# 21        Gary Roxburgh     37
# 22          Dawn Devito     37
# 23          Cindy Lopez     37
# 24          Glenn Dubin     36
# 25            Eva Dubin     36
# 26         Celina Dubin     35
# 27      Chauntae Davies     35
# 28    Didier Cazaudumec     32
# ...

# %%
df_passangers_total = df_passangers_total.iloc[1:]
df_passangers_total = df_passangers_total.reset_index(drop=True)

# %% [markdown]
# #### Bar Plot - Who Flew most with Jeffrey Epstein ?

# %%
df_top20 = df_passangers_total.nlargest(20, "Count")

plt.figure(figsize=(10,6))

sns.barplot(data=df_top20, x="Count", y="Passenger")

plt.title("Top 20 Most Frequent Passengers")
plt.xlabel("Flight Count")
plt.ylabel("")

plt.tight_layout()
plt.show()

# %%
# Who the hell is AP
df_all = df_persons.stack().str.strip()
df_all = df_all[df_all != ""]

df_ap = df_all[df_all.str.match(r"^A\w*\s+P\w*", case=False)]

df_ap_unique = df_ap.unique()
print(df_ap_unique)
# Out:
# ['Adam Perry Lang' 'Adam PerryLang; Adam Lang' 'Alberto Pinto'
#  'Andres Pastrana'
#  'Andres Pastrana Arango; Andrés Pastrana Arango; Arango; Andrés Arango'
#  'AI pioneer named in Giuffre court filings; deceased.'
#  'Arnold Paul Prosperi' 'Arnold Prosperi; Prosperi'
#  'A person the author met at the bike rally.'
#  'Argentine polo player; name appears in an Epstein social contact list for a William Astor dinner (2010); no allegations.'
#  'Albuquerque President.'
#  'AI pioneer who attended Epstein-funded AI conference on Little St. James; Manhattan neighbor of Epstein; died 2023.'
#  'Associate Professor of Medicine at Harvard Medical School, expert on the placebo effect, in direct email contact with Jeffrey Epstein who claimed to have funded his research.']

# %% [markdown]
# ### Who talked with JE the most ?

# %%
df_emails.head(10)
# Out:
#         Date                                               From  \
# 0 2019-07-14            Quora Digest [digest-noreply@quora.com]
# 1 2019-07-09  Intelligence Squared [info@intelligencesquared...
# 2 2019-07-07            Quora Digest [digest-noreply@quora.com]
# 3 2019-07-06                                    Reid Weingarten
# 4 2019-07-06                                    Jeffrey Epstein
# 5 2019-07-06                                    Reid Weingarten
# 6 2019-07-06                                    Jeffrey Epstein
# 7 2019-07-06                                    Reid Weingarten
# 8 2019-07-06                                    Jeffrey Epstein
# 9 2019-07-06                                    Reid Weingarten
#
#                 From Email                     To  \
# 0                     <NA>  jeevacation@gmail.com
# 1                     <NA>  jeevacation@gmail.com
# 2                     <NA>  jeevacation@gmail.com
# 3  rweingarten@steptoe.com        Jeffrey Epstein
# ...

# %%
df_emails.shape
df_emails_ft = df_emails.drop(["Subject", "Body (excerpt)","Tags"], axis=1)
# Out:
#         Date                                               From  \
# 0 2019-07-14            Quora Digest [digest-noreply@quora.com]
# 1 2019-07-09  Intelligence Squared [info@intelligencesquared...
# 2 2019-07-07            Quora Digest [digest-noreply@quora.com]
# 3 2019-07-06                                    Reid Weingarten
# 4 2019-07-06                                    Jeffrey Epstein
#
#                 From Email                     To
# 0                     <NA>  jeevacation@gmail.com
# 1                     <NA>  jeevacation@gmail.com
# 2                     <NA>  jeevacation@gmail.com
# 3  rweingarten@steptoe.com        Jeffrey Epstein
# 4    je@jeffreyepstein.com        Reid Weingarten

# %%
df_emails_ft.head(30)
# Out:
#          Date                                               From  \
# 0  2019-07-14            Quora Digest [digest-noreply@quora.com]
# 1  2019-07-09  Intelligence Squared [info@intelligencesquared...
# 2  2019-07-07            Quora Digest [digest-noreply@quora.com]
# 3  2019-07-06                                    Reid Weingarten
# 4  2019-07-06                                    Jeffrey Epstein
# 5  2019-07-06                                    Reid Weingarten
# 6  2019-07-06                                    Jeffrey Epstein
# 7  2019-07-06                                    Reid Weingarten
# 8  2019-07-06                                    Jeffrey Epstein
# 9  2019-07-06                                    Reid Weingarten
# 10 2019-07-06                                    Jeffrey Epstein
# 11 2019-07-06                                    Jeffrey Epstein
# 12 2019-07-06       Weingarten, Reid [reid.weingarten@gmail.com]
# ...
